# %% [markdown]
# <h1 style="text-align: center;">Wine Clustering Analysis</h1>

# %% [markdown]
# ## Project Purpose
#
# The aim of this project is to explore **unsupervised machine learning** by grouping wine samples into meaningful clusters based on their numerical characteristics.
#
# This notebook will focus on understanding the clustering workflow, including data inspection, preprocessing, cluster selection, model evaluation, and interpretation of the resulting groups.

# %% [markdown]
# -------------------
# ## Data Import

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("wine-clustering.csv")

# %% [markdown]
# ----------------
# ## EDA (Exploratory Data Analysis)
#
# This section will perform an initial statistical inspection of the wine dataset to understand its structure, data types, missing values, duplicates, feature ranges, and overall distribution before moving to visualization and clustering.

# %%
data.head()
# Out:
#    Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0    14.23        1.71  2.43          15.6        127           2.80
# 1    13.20        1.78  2.14          11.2        100           2.65
# 2    13.16        2.36  2.67          18.6        101           2.80
# 3    14.37        1.95  2.50          16.8        113           3.85
# 4    13.24        2.59  2.87          21.0        118           2.80
#
#    Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    OD280  Proline
# 0   3.92     1065
# 1   3.40     1050
# 2   3.17     1185
# 3   3.45     1480
# 4   2.93      735

# %%
data.shape
# Out:
# (178, 13)

# %%
data.describe()
# Out:
#           Alcohol  Malic_Acid         Ash  Ash_Alcanity   Magnesium  \
# count  178.000000  178.000000  178.000000    178.000000  178.000000
# mean    13.000618    2.336348    2.366517     19.494944   99.741573
# std      0.811827    1.117146    0.274344      3.339564   14.282484
# min     11.030000    0.740000    1.360000     10.600000   70.000000
# 25%     12.362500    1.602500    2.210000     17.200000   88.000000
# 50%     13.050000    1.865000    2.360000     19.500000   98.000000
# 75%     13.677500    3.082500    2.557500     21.500000  107.000000
# max     14.830000    5.800000    3.230000     30.000000  162.000000
#
#        Total_Phenols  Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  \
# count     178.000000  178.000000            178.000000       178.000000
# mean        2.295112    2.029270              0.361854         1.590899
# std         0.625851    0.998859              0.124453         0.572359
# min         0.980000    0.340000              0.130000         0.410000
# 25%         1.742500    1.205000              0.270000         1.250000
# 50%         2.355000    2.135000              0.340000         1.555000
# 75%         2.800000    2.875000              0.437500         1.950000
# max         3.880000    5.080000              0.660000         3.580000
#
#        Color_Intensity         Hue       OD280      Proline
# count       178.000000  178.000000  178.000000   178.000000
# mean          5.058090    0.957449    2.611685   746.893258
# std           2.318286    0.228572    0.709990   314.907474
# min           1.280000    0.480000    1.270000   278.000000
# 25%           3.220000    0.782500    1.937500   500.500000
# 50%           4.690000    0.965000    2.780000   673.500000
# 75%           6.200000    1.120000    3.170000   985.000000
# max          13.000000    1.710000    4.000000  1680.000000

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Alcohol               178 non-null    float64
#  1   Malic_Acid            178 non-null    float64
#  2   Ash                   178 non-null    float64
#  3   Ash_Alcanity          178 non-null    float64
#  4   Magnesium             178 non-null    int64
#  5   Total_Phenols         178 non-null    float64
#  6   Flavanoids            178 non-null    float64
#  7   Nonflavanoid_Phenols  178 non-null    float64
#  8   Proanthocyanins       178 non-null    float64
#  9   Color_Intensity       178 non-null    float64
#  10  Hue                   178 non-null    float64
#  11  OD280                 178 non-null    float64
#  12  Proline               178 non-null    int64
# dtypes: float64(11), int64(2)
# memory usage: 18.2 KB

# %%
data.nunique()
# Out:
# Alcohol                 126
# Malic_Acid              133
# Ash                      79
# Ash_Alcanity             63
# Magnesium                53
# Total_Phenols            97
# Flavanoids              132
# Nonflavanoid_Phenols     39
# Proanthocyanins         101
# Color_Intensity         132
# Hue                      78
# OD280                   122
# Proline                 121
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Initial Statistical EDA Evaluation
#
# The dataset contains **178 rows and 13 numerical features**, with no missing values or duplicate records. The features have noticeably different numerical ranges, indicating that scaling will be necessary before applying distance-based clustering methods such as K-Means.
#
# The descriptive statistics also suggest a few possible outliers in features such as `Ash_Alcanity`, `Color_Intensity`, and `Proline`. These values are not necessarily problematic, but they should be examined further through visualization before preprocessing decisions are made.
#
# Overall, the dataset appears clean and suitable for clustering, with scaling and outlier inspection being the main considerations before modelling.

# %% [markdown]
# -------------
# ## Exploratory Data Analysis Using Visualization
#
# This section will visually examine the distribution, spread, outliers, and relationships among the numerical features. Histograms and box plots will be used to inspect individual features, while a correlation heatmap and selected scatter plots will help identify relationships and possible grouping patterns that may be relevant for clustering.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
for column in data.columns.to_list():
    fig = plt.figure(figsize=(12,8))
    ax0 = fig.add_subplot(1,2,1)
    ax1 = fig.add_subplot(1,2,2)

    sns.boxplot(data=data, y=column, color="steelblue", ax=ax0)
    ax0.set_title(column)
    ax0.set_xlabel(column)

    sns.histplot(data=data, x=column, color="steelblue", ax=ax1)
    ax1.set_title(column)
    ax1.set_xlabel(column)

    plt.show()

# %% [markdown]
# ### Visualization Evaluation
#
# #### Clean distributions with no obvious outliers
# - Alcohol
# - Total_Phenols
# - Nonflavanoid_Phenols
#
# #### Mostly balanced distributions with a few outliers
# - Ash
# - Ash_Alcanity
# - Hue
#
# #### Right-skewed distributions with upper-end outliers
# - Malic_Acid
# - Magnesium
# - Proanthocyanins
# - Color_Intensity
#
# #### Right-skewed distribution with no obvious outliers
# - Proline
#
# #### Irregular / non-normal distributions
# - Flavanoids
# - OD280
#
# ### Overall Observation
#
# The features show different patterns of skewness, outlier presence, and numerical scale. These differences should be considered when selecting an appropriate scaling method before clustering.

# %% [markdown]
# ------------------------------------------------
# ## Correlation Analysis
#
# This section will examine the relationships between the numerical features using a **correlation heatmap**. The aim is to identify features that have strong positive or negative relationships and to understand which variables tend to change together.
#
# This analysis can also help identify highly correlated features that may contain similar or overlapping information before moving toward clustering.

# %%
plt.figure(figsize=(20,15))
sns.heatmap(data=data.corr(), annot=True, fmt=".3f", cmap="Blues")
plt.show()

# %% [markdown]
# ### Correlation Evaluation
#
# Most features do not show extremely high correlation, suggesting that they retain distinct information. The strongest relationship is between Total_Phenols and Flavanoids, with a few other moderate relationships also present.
#
# Overall, there are no near-duplicate features based on correlation alone.

# %% [markdown]
# -----------------
# ## K-Means Clustering — Experiment 1
#
# This will be the first clustering experiment on the wine dataset. To establish a simple baseline, **StandardScaler will be applied to all numerical features** so that differences in feature magnitude do not dominate the distance calculations used by K-Means.
#
# The initial K-Means results will then be evaluated to understand how well the data forms clusters under this basic preprocessing approach. Based on the results, further decisions can be made regarding whether different scaling methods, transformations, or other preprocessing adjustments are necessary.

# %%
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
data_exp1 = data.copy()

# %%
scaler = StandardScaler()
data_exp1 = scaler.fit_transform(data_exp1)
data_exp1 = pd.DataFrame(data_exp1, columns=data.columns)

# %%
interias = []
labels = []
centers = []

# %%
for n in range(2,9):
    model = KMeans(n_clusters=n, init="k-means++", n_init="auto", max_iter=300, tol=1e-4, random_state=1,algorithm="lloyd")
    model.fit(data_exp1)
    interias.append(model.inertia_)
    labels.append(model.labels_)
    centers.append(model.cluster_centers_)

# %%
plt.figure(figsize=(16,9))
plt.plot(range(2,9), interias)
plt.xlim(1,9)
plt.xlabel("Number of Clusters")
plt.ylabel("Interia")
plt.title("Elbow Method")
plt.grid()
plt.show()

# %%
silhouette_scores = []
for i in range(len(labels)):
    score = silhouette_score(data_exp1, labels[i])
    silhouette_scores.append(score)

# %%
plt.figure(figsize=(20,8))
plt.plot(range(2,9), silhouette_scores)
plt.xlabel("Number of Clusters")
plt.ylabel("Silhouette Score")
plt.title("Silhouette Score by Number of Clusters")
plt.grid()
plt.show()

# %% [markdown]
# ### Cluster Count Evaluation
#
# The Elbow Method indicated that the most reasonable number of clusters lies around **3 to 4**, while the Silhouette Score reached its highest value at **3 clusters**. Based on both methods, **`k = 3`** was selected as the best choice for the first K-Means experiment.

# %% [markdown]
# -----------
# ## Final K-Means Model — Experiment 1
#
# Based on the Elbow Method and Silhouette Score, **3 clusters** were selected as the most suitable choice for this experiment. A final K-Means model will now be trained using `k = 3` on the standardized dataset.
#
# After fitting the model, the resulting cluster assignments, cluster sizes, and centroid values will be examined to better understand how the observations have been grouped.

# %%
model = KMeans(n_clusters=3, init="k-means++", n_init="auto", max_iter=300, tol=1e-4, random_state=1,algorithm="lloyd")

# %%
model.fit(data_exp1)
# Out:
# KMeans(n_clusters=3, random_state=1)

# %%
cluster_sample_size = np.bincount(model.labels_)
cluster_sample_size
# Out:
# array([66, 51, 61])

# %%
centers_df = pd.DataFrame(model.cluster_centers_, columns=data.columns)
centers_df
# Out:
#     Alcohol  Malic_Acid       Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0 -0.939003   -0.391966 -0.439201      0.208988  -0.463774      -0.053348
# 1  0.164907    0.871547  0.186898      0.524367  -0.075473      -0.979330
# 2  0.878097   -0.304576  0.318942     -0.664524   0.564888       0.876505
#
#    Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity  \
# 0    0.066904             -0.019822         0.064792        -0.882075
# 1   -1.215248              0.726064        -0.779706         0.941539
# 2    0.943639             -0.585590         0.581783         0.167188
#
#         Hue     OD280   Proline
# 0  0.452982  0.289738 -0.756026
# 1 -1.164789 -1.292412 -0.407088
# 2  0.483728  0.767053  1.158347

# %%
plt.figure(figsize=(18,12))
sns.heatmap(centers_df, annot=True, fmt=".2f", cmap="coolwarm")
plt.show()

# %% [markdown]
# ----------------
# ## PCA Based Cluster Visualization
#
# This section will use Principal Component Analysis (PCA) to reduce the 13 standardized features into two principal components. These components will be used to visualize the K-Means clusters in two dimensions and assess how clearly the three groups are separated.

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)

# %%
pca_data = pca.fit_transform(data_exp1)

# %%
pca_df = pd.DataFrame(pca_data, columns=['PC1', 'PC2'])
pca_df['Clusters'] = model.labels_

# %%
plt.figure(figsize=(16,10))
sns.scatterplot(data=pca_df, x="PC1", y='PC2', hue='Clusters', palette="Set1", s=70)
plt.title("PCA based clustering")
plt.show()

# %% [markdown]
# ### PCA Visualization Evaluation
#
# The PCA visualization shows three recognizable cluster regions with limited overlap. Although the silhouette score indicates only moderate separation, the clusters still appear meaningfully structured in the 2D projection, suggesting that K-Means captured useful grouping patterns in the standardized data.

# %% [markdown]
# -----------
# ## PCA Explained Variance
#
# This section will examine how much of the original dataset’s variation is captured by the first two principal components. This helps determine how much information is represented in the 2D PCA visualization and how confidently the cluster plot can be interpreted.

# %%
pca.explained_variance_ratio_
# Out:
# array([0.36198848, 0.1920749 ])

# %%
pca.explained_variance_ratio_.sum()
# Out:
# np.float64(0.5540633835693527)

# %% [markdown]
# ----------------
# ## Experiment 1 Conclusion
#
# The first K-Means experiment produced three reasonably balanced and distinct clusters. The Elbow Method and Silhouette Score supported `k = 3`, while centroid analysis showed clear differences in feature profiles across the clusters. PCA visualization also showed visible separation, although the first two components captured only about 55% of the total variance.
#
# Overall, the baseline clustering is promising, but the moderate silhouette score suggests that alternative preprocessing methods may be worth testing in a second experiment.

# %% [markdown]
# -----
# ## K-Means Clustering — Experiment 2
#
# This experiment will test whether a more targeted preprocessing strategy improves the clustering results. Instead of applying the same scaler to every feature, the columns will be divided based on the patterns observed during EDA.
#
# Features that are relatively clean will use **StandardScaler**, while features containing noticeable outliers will use **RobustScaler** to reduce the influence of extreme values. After preprocessing, K-Means will be evaluated again using the same approach as Experiment 1 so the results can be compared fairly.

# %%
data_exp2 = data.copy()

# %%
standard_columns = ["Alcohol", "Total_Phenols", "Nonflavanoid_Phenols", "Flavanoids", "OD280", "Proline"]

robust_columns = ["Ash", "Ash_Alcanity", "Hue", "Malic_Acid", "Magnesium", "Proanthocyanins","Color_Intensity"]

# %%
data_exp2[standard_columns] = scaler.fit_transform(data_exp2[standard_columns])

# %%
r_scalar = RobustScaler()
data_exp2[robust_columns] = r_scalar.fit_transform(data_exp2[robust_columns])

# %%
interias = []
labels = []
centers = []

# %%
for n in range(2,10):
    model = KMeans(n_clusters=n, init="k-means++", max_iter=300, n_init='auto', algorithm='lloyd', random_state=1, tol=1e-4)
    model.fit(data_exp2)
    interias.append(model.inertia_)
    labels.append(model.labels_)
    centers.append(model.cluster_centers_)

# %%
plt.figure(figsize=(22,9))
plt.plot(range(2,10), interias, linewidth=4)
plt.title("Elbow Method", fontsize=16, fontweight='bold', pad=15)
plt.xlabel("Number of Clusters", fontsize=13)
plt.tick_params(axis='both', labelsize=10, colors='black')
plt.ylabel("Interia", fontsize=13)
plt.grid(alpha=1)
plt.show()

# %%
silhouette_scores = []
for i in range(len(labels)):
    score = silhouette_score(data_exp2, labels[i])
    silhouette_scores.append(score)

# %%
plt.figure(figsize=(22,9))
plt.plot(range(2,10), silhouette_scores, linewidth=4)
plt.title("Silhouette scores", fontsize=16, fontweight='bold', pad=15)
plt.xlabel("Number of Clusters", fontsize=13)
plt.tick_params(axis='both', labelsize=10, colors='black')
plt.ylabel("Scores", fontsize=13)
plt.grid(alpha=1)
plt.show()

# %% [markdown]
# ## Experiment 2 Cluster Count Evaluation
#
# The Elbow Method again suggested 3 to 4 clusters as the most reasonable range, while the Silhouette Score reached its highest value at k = 3. The score is slightly better than in Experiment 1, suggesting that the column-specific scaling strategy produced a small improvement in cluster separation.
#
# Based on both methods, 3 clusters will be used for the final K-Means model in Experiment 2.

# %% [markdown]
# ---
# ## Final Experiment 2

# %%
model = KMeans(n_clusters=3, init="k-means++", n_init="auto", max_iter=300, tol=1e-4, random_state=1,algorithm="lloyd")

# %%
model.fit(data_exp2)
# Out:
# KMeans(n_clusters=3, random_state=1)

# %%
cluster_sample_size = np.bincount(model.labels_)
cluster_sample_size
# Out:
# array([62, 55, 61])

# %%
centers_df = pd.DataFrame(model.cluster_centers_, columns=data.columns)

# %%
plt.figure(figsize=(22,12))
sns.heatmap(centers_df, annot=True, fmt=".2f", cmap="coolwarm")
plt.show()

# %% [markdown]
# ## Experiment 2 Cluster Profile Evaluation
#
# The centroid heatmap shows that the three clusters are characterized by noticeably different feature patterns. Cluster 2 is generally high in features such as Alcohol, Total_Phenols, Flavanoids, OD280, and Proline, while Cluster 1 shows almost the opposite pattern for several of these features and is higher in Malic_Acid and Color_Intensity. Cluster 0 remains more moderate overall but still has its own distinct profile.

# %% [markdown]
# ---
# ## PCA-Based Cluster Visualization — Experiment 2
#
# This section will use PCA to reduce the Experiment 2 preprocessed data into two principal components for visualization. The resulting scatter plot will help assess how clearly the three K-Means clusters are separated under the column-specific scaling strategy.

# %%
pca_data = pca.fit_transform(data_exp2)

# %%
pca_exp2 = pd.DataFrame(pca_data, columns=['PC1', 'PC2'])
pca_exp2['clusters'] = model.labels_

# %%
plt.figure(figsize=(22,11))
ax = sns.scatterplot(data=pca_exp2, x='PC1', y='PC2', hue='clusters', palette='Set1', s=100, linewidth=1.5, edgecolor='black')
ax.set_title("PCA for Experiment 2", fontsize=15, fontweight='bold',pad=18)
ax.set_xlabel('PC1', fontsize=13, fontweight='bold')
ax.set_ylabel('PC2', fontsize=13, fontweight='bold')
ax.tick_params(axis='both', labelsize=10, colors='black')
ax.legend()
plt.show()

# %% [markdown]
# ## PCA Explained Variance
#
# This section will examine how much of the original dataset’s variation is captured by the first two principal components. This helps determine how much information is represented in the 2D PCA visualization and how confidently the cluster plot can be interpreted.

# %%
pca.explained_variance_ratio_.sum()
# Out:
# np.float64(0.5941598646992894)

# %% [markdown]
# ## PCA Conclusion
#
# The first two principal components explain about 59.4% of the total variance, which is an improvement over Experiment 1. The PCA scatter plot also shows slightly clearer separation between the three clusters, although around 40.6% of the variance remains outside the 2D representation.

# %% [markdown]
# ----
# ## Experiment 2 Overall Conclusion
#
# Experiment 2 produced a small but noticeable improvement over the baseline. The best cluster count remained k = 3, while the silhouette score increased slightly and the PCA visualization showed somewhat clearer cluster separation. The centroid profiles also remained distinct and interpretable.
#
# Overall, the column-specific scaling strategy performed slightly better than applying StandardScaler to all features, suggesting that handling outlier-sensitive features with RobustScaler was beneficial.

# %% [markdown]
# ---
# # Final Clustering Conclusion
#
# This project successfully applied an unsupervised learning workflow to group wine samples based on their numerical characteristics. K-Means consistently identified **three meaningful clusters**, supported by both the Elbow Method and Silhouette Score.
#
# The first experiment established a baseline using StandardScaler across all features, while the second experiment used column-specific scaling to better account for outlier-sensitive features. Experiment 2 produced a small improvement in silhouette score and PCA separation, suggesting that the targeted preprocessing strategy was slightly more effective.
#
# The cluster centroid analysis showed that each cluster had a distinct feature profile, while PCA provided a useful two-dimensional representation of the grouping structure. Although the clusters were not perfectly separated and some overlap remained, the results were consistent, interpretable, and meaningful.
#
# Overall, the project achieved its main goal of understanding and applying the complete K-Means clustering workflow, including preprocessing, cluster selection, evaluation, interpretation, and visualization.
